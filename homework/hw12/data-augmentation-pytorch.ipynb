# %% [markdown]
# # Training neural network: Data augmentation
#
# Tiếp nối bài thực hành trên lớp, bài tập về nhà này vẫn sử dụng MNIST là tập dữ liệu thử nghiệm. Mục tiêu là cải thiện hiệu suất của mô hình bằng các kỹ thuật Augmentation nhằm tăng cường số lượng dữ liệu

# %%
# !pip install "numpy<1.20"
# Out:
# Collecting numpy<1.24
#   Downloading numpy-1.23.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Downloading numpy-1.23.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 96.9 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.3 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.23.5 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.23.5 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.23.5 which is incompatible.
# datasets 4.1.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# woodwork 0.31.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# featuretools 1.31.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# bayesian-optimization 3.1.0 requires numpy>=1.25; python_full_version < "3.13", but you have numpy 1.23.5 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.23.5 which is incompatible.
# mne 1.10.1 requires numpy<3,>=1.25, but you have numpy 1.23.5 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.23.5 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.23.5 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# scikit-image 0.25.2 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.23.5 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0a1 which is incompatible.
# imbalanced-learn 0.13.0 requires numpy<3,>=1.24.3, but you have numpy 1.23.5 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# albumentations 2.0.8 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# pandas-gbq 0.29.2 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# xarray-einstats 0.9.1 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# xarray 2025.7.1 requires numpy>=1.26, but you have numpy 1.23.5 which is incompatible.
# transformers 4.53.3 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 1.0.0rc2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# albucore 0.0.24 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# db-dtypes 1.4.3 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# chex 0.1.90 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.23.5 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# pymc 5.25.1 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# blosc2 3.6.1 requires numpy>=1.26, but you have numpy 1.23.5 which is incompatible.
# Successfully installed numpy-1.23.5

# %%
import warnings
warnings.filterwarnings('ignore')
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from keras.datasets import mnist
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %load_ext tensorboard
# !rm -rf './graph/dropout/dropout=0.5,relu/'
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print('Training image: ', x_train.shape)
print('Testing image: ', x_test.shape)
print('Training label: ', y_train.shape)
print('Testing label: ', y_test.shape)
# Out:
# Training image:  (60000, 28, 28)
# Testing image:  (10000, 28, 28)
# Training label:  (60000,)
# Testing label:  (10000,)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
class SimpleModel(nn.Module):
    def __init__(self, dropout_rate):
        super(SimpleModel, self).__init__()
        self.dense_1 = nn.Linear(28*28, 128)
        self.dropout = nn.Dropout(dropout_rate)
        self.dense_2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.dense_1(x)
        x = self.relu(x)
        x = self.dropout(x)
        output = F.log_softmax(self.dense_2(x))
        
        return output

# %% [markdown]
# # Check model parameter

# %%
simple_model = SimpleModel(dropout_rate = 0.5).cuda()
for param in simple_model.parameters():
    if param.requires_grad:
        print('param autograd')
        break

input = torch.rand(1, 28, 28).cuda()
output = simple_model(input)  # type: torch.Tensor

model_parameters = filter(lambda p: p.requires_grad, simple_model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print('Number of parameter:', params)
# Out:
# param autograd
# Number of parameter: 101770

# %% [markdown]
# ## Tăng thêm dữ liệu (data augmentation) với thư viện imgaug
#
# Trong phần thực hành này, chúng ta sẽ làm quen với các phương pháp tăng dữ liệu cho bài toán xử lý ảnh, các phương pháp này hoàn toàn có thể lập trình sử dụng thư viện numpy (vì bản chất của phương pháp là ta thao tác trên ma trận biểu diễn ảnh). Tuy nhiên, để việc lập trình được nhanh chóng, chúng ta sẽ làm quen với một thư viện rất mạnh mẽ, giúp ta nhanh chóng cài đặt nhiều phương pháp tăng dữ liệu hiệu quả khác nhau: thư viện imgaug
#
# Để cài đặt imgaug, ta sử dụng lệnh:
#
# pip install imgaug
#
# pip install scikit-image --upgrade

# %%
# Cài đặt thư viện

######################
### YOUR CODE HERE ###
# !pip install imgaug
# !pip install --upgrade imgaug
# !pip install scikit-image --upgrade
######################
# Out:
# Requirement already satisfied: imgaug in /usr/local/lib/python3.11/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.15.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from imgaug) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from imgaug) (3.7.2)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.11/dist-packages (from imgaug) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from imgaug) (4.12.0.88)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from imgaug) (2.37.0)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.11/dist-packages (from imgaug) (2.1.2)
# Collecting numpy>=1.15 (from imgaug)
#   Downloading numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (3.5)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (1.4.8)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (2.9.0.post0)
#   Using cached numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.6 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.3 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.1.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0a1 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# pandas-gbq 0.29.2 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# transformers 4.53.3 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 1.0.0rc2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed numpy-2.2.6
# Requirement already satisfied: imgaug in /usr/local/lib/python3.11/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.11/dist-packages (from imgaug) (2.2.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.15.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from imgaug) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from imgaug) (3.7.2)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.11/dist-packages (from imgaug) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from imgaug) (4.12.0.88)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from imgaug) (2.37.0)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.11/dist-packages (from imgaug) (2.1.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (3.5)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (1.4.8)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (2.9.0.post0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.2.6)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)

# %%
from imgaug import augmenters as iaa

# %% [markdown]
# Để tìm hiểu lần lượt các phương pháp, thử áp dụng trên ảnh cat.jpg trong thư mục bài thực hành:

# %%
image = cv2.imread('/kaggle/input/cat-jpg/cat.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Các phương pháp thường sử dụng
#
# Các phương pháp hay được sử dụng nhất trong các bài toán xử lý ảnh có thể tham khảo tại: https://imgaug.readthedocs.io/en/latest/source/augmenters.html

# %% [markdown]
# 1. CropAndPad: Cắt hoặc thêm các pixel vào ảnh.

# %%
# Sử dụng hàm CropAndPad với tham số percent=(-0.25, 0.25)

######################
### YOUR CODE HERE ###
crop_and_pad = iaa.CropAndPad(percent=(-0.25, 0.25))
######################

plt.imshow(cv2.cvtColor(crop_and_pad.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 2. Flip: Flip left-right hoặc Flip up-down một số ảnh trong tập ảnh truyền vào

# %%
# Flip left-right sử dụng hàm Fliplr với tham số 1.0

######################
### YOUR CODE HERE ###
flip_lr = iaa.Fliplr(1.0)
######################

plt.imshow(cv2.cvtColor(flip_lr.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Flip up-down sử dụng hàm Flipud với tham số 1.0

######################
### YOUR CODE HERE ###
flip_ud = iaa.Flipud(1.0)
######################

plt.imshow(cv2.cvtColor(flip_ud.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Affine: Các phép biến đổi affine như scale, rotate, translate:

# %%
# Biến đổi affine dùng hàm Affine với các tham số scale=(0.5, 1.5), rotate=(-15,15), translate_percent=(-0.2, 0.2)

######################
### YOUR CODE HERE ###
affine = iaa.Affine(scale=(0.5, 1.5), rotate=(-15, 15), translate_percent=(-0.2, 0.2))
######################

plt.imshow(cv2.cvtColor(affine.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Blur: Sử dụng các bộ lọc Gaussian hoặc Mean:

# %%
# Sử dụng hàm AverageBlur để thực hiện Mean filter với tham số k = (11,31), GaussianBlur để thực hiện Gausian Blur với Sigma = (5,15)

######################
### YOUR CODE HERE ###
avg_blur = iaa.AverageBlur(k = (11, 31))
gauss_blur = iaa.GaussianBlur(sigma=(5,15))
######################

plt.imshow(cv2.cvtColor(avg_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(gauss_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Dropout: Biến đổi ngẫu nhiên một phần ảnh thành các pixel đen

# %%
# Dropout với tham số p = (0, 0.2) 

######################
### YOUR CODE HERE ###
dropout = iaa.Dropout(p=(0, 0.2))
######################

plt.imshow(cv2.cvtColor(dropout.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Kết hợp nhiều augmenter
#
# Trong thực tế, có nhiều chiến lược trong việc thực hiện các augmenter khác nhau, thư viện imgaug cũng hỗ trợ một số hàm để thực hiện công việc này:

# %% [markdown]
# - Sequential: Áp dụng các augmenter lần lượt theo thứ tự truyền vào:

# %%
aug = iaa.Sequential([
    iaa.Affine(translate_px={"x":(-40, 40)}),
    iaa.AdditiveGaussianNoise(scale=0.1*255)
])

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - SomeOf: Áp dụng ngẫu nhiên một vài augmenter trong list các augmenter:

# %% [markdown]
# - Sometimes: Áp dụng augmenter với xác suất p:

# %% [markdown]
# ### Kết hợp cùng thư viện Keras
#
# Bây giờ chúng ta sẽ sử dụng các augmenter đã viết để thực hiện augment image trong quá trình huấn luyện mạng với thư viện Keras.

# %% [markdown]
# - Bước 1: Khởi tạo Augmenter:

# %%
 # Sử dụng hàm Dropout với tham số p=(0, 0.002)

######################
### YOUR CODE HERE ###
our_arg = iaa.Dropout(p=(0, 0.002))
######################

# %% [markdown]
# - Bước 2: Xây dựng generator:

# %%
class Generator(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels

    def __len__(self):
        return self.images.shape[0]

    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

# %%
training_data = Generator(x_train, y_train)
train_dataloader = DataLoader(training_data, batch_size=32, shuffle=True)

# %%
test_data = Generator(x_test, y_test)
test_dataloader = DataLoader(test_data, batch_size=32, shuffle=True)

# %% [markdown]
# Quan sát thử kết quả của generator bên trên:

# %%
for (batch_idx, target_tuple) in enumerate(train_dataloader):
    print(target_tuple[0].shape)
    for i in range(32):
        plt.subplot(4, 8, i + 1), plt.imshow(target_tuple[0][i], cmap='gray')
    plt.show()
    break
# Out:
# torch.Size([32, 28, 28])

# %% [markdown]
# - Bước 3: Train model với fit_generator:

# %%
use_cuda = torch.cuda.is_available()  #GPU cuda
best_loss = float('inf')

model = SimpleModel(dropout_rate = 0.5)

optimizer = torch.optim.Adadelta(model.parameters())

if use_cuda:
    model = torch.nn.parallel.DataParallel(model.cuda())   # , device_ids=[0, 1, 2, 3]
    torch.backends.cudnn.benchmark = True

# %%
def train(epoch):
    print('\n ############################# Train phase, Epoch: {} #############################'.format(epoch))
    model.train()
    train_loss = 0

    print('\nLearning rate at this epoch is: ', optimizer.param_groups[0]['lr'], '\n')

    for (batch_idx, target_tuple) in enumerate(train_dataloader):
        if use_cuda:
            target_tuple = [target_tensor.cuda(non_blocking=True) for target_tensor in target_tuple]

        images, labels = target_tuple
        # Convert label to long type pytorch
        labels = torch.tensor(labels,dtype=torch.long)

        optimizer.zero_grad()  # zero the gradient buff
        output_tuple = model(images)

        loss = F.nll_loss(output_tuple, labels).cuda()

        loss.backward()  # retain_graph=True
        optimizer.step()

        train_loss += loss.item()  # loss　　　
        print('########################### Epoch:', epoch, ', --  batch:',  batch_idx, '/', len(train_dataloader), ',   ',
              'Train loss: %.3f, accumulated average loss: %.3f ##############################' % (loss.item(), train_loss / (batch_idx + 1)))

    global best_loss
    train_loss /= len(train_dataloader)
    if train_loss < best_loss:
      noti = 'best_'
      best_loss = train_loss
    else:
      noti = ''
    print('saving...')
    state = {
      'weights': model.module.state_dict(),
      'optimizer_weight': optimizer.state_dict(),
      'train_loss': train_loss,
      'epoch': epoch,
    }
    os.makedirs('checkpoints', exist_ok=True)
    torch.save(state, 'checkpoints/model_' + noti + str(epoch) + '_epoch.pth')

# %%
def test(epoch):
    print('\n ############################# Test phase, Epoch: {} #############################'.format(epoch))
    model.eval()
    with torch.no_grad():
        test_loss = 0

        for (batch_idx, target_tuple) in enumerate(test_dataloader):
            if use_cuda:
                target_tuple = [target_tensor.cuda(non_blocking=True) for target_tensor in target_tuple]

            images, labels = target_tuple
            # Convert label to long type pytorch
            labels = torch.tensor(labels,dtype=torch.long)
            output_tuple = model(images)

            loss = F.nll_loss(output_tuple, labels).cuda()

            test_loss += loss.item()  # loss　　　
            print('########################### Epoch:', epoch, ', --  batch:',  batch_idx, '/', len(test_dataloader), ',   ',
                  'Test loss: %.3f, accumulated average loss: %.3f ##############################' % (loss.item(), test_loss / (batch_idx + 1)))

# %%
no_epoch = 5
for epoch in range(no_epoch):
    train(epoch)
    test(epoch)
# Out:
#  ############################# Train phase, Epoch: 0 #############################
#
# Learning rate at this epoch is:  1.0
#
# ########################### Epoch: 0 , --  batch: 0 / 1875 ,    Train loss: 2.292, accumulated average loss: 2.292 ##############################
# ########################### Epoch: 0 , --  batch: 1 / 1875 ,    Train loss: 2.329, accumulated average loss: 2.310 ##############################
# ########################### Epoch: 0 , --  batch: 2 / 1875 ,    Train loss: 2.244, accumulated average loss: 2.288 ##############################
# ########################### Epoch: 0 , --  batch: 3 / 1875 ,    Train loss: 2.172, accumulated average loss: 2.259 ##############################
# ########################### Epoch: 0 , --  batch: 4 / 1875 ,    Train loss: 2.121, accumulated average loss: 2.232 ##############################
# ########################### Epoch: 0 , --  batch: 5 / 1875 ,    Train loss: 2.086, accumulated average loss: 2.207 ##############################
# ########################### Epoch: 0 , --  batch: 6 / 1875 ,    Train loss: 2.037, accumulated average loss: 2.183 ##############################
# ########################### Epoch: 0 , --  batch: 7 / 1875 ,    Train loss: 1.923, accumulated average loss: 2.151 ##############################
# ########################### Epoch: 0 , --  batch: 8 / 1875 ,    Train loss: 1.920, accumulated average loss: 2.125 ##############################
# ########################### Epoch: 0 , --  batch: 9 / 1875 ,    Train loss: 1.827, accumulated average loss: 2.095 ##############################
# ########################### Epoch: 0 , --  batch: 10 / 1875 ,    Train loss: 1.712, accumulated average loss: 2.060 ##############################
# ########################### Epoch: 0 , --  batch: 11 / 1875 ,    Train loss: 1.727, accumulated average loss: 2.033 ##############################
# ########################### Epoch: 0 , --  batch: 12 / 1875 ,    Train loss: 1.801, accumulated average loss: 2.015 ##############################
# ########################### Epoch: 0 , --  batch: 13 / 1875 ,    Train loss: 1.684, accumulated average loss: 1.991 ##############################
# ########################### Epoch: 0 , --  batch: 14 / 1875 ,    Train loss: 1.547, accumulated average loss: 1.962 ##############################
# ########################### Epoch: 0 , --  batch: 15 / 1875 ,    Train loss: 1.502, accumulated average loss: 1.933 ##############################
# ########################### Epoch: 0 , --  batch: 16 / 1875 ,    Train loss: 1.415, accumulated average loss: 1.902 ##############################
# ########################### Epoch: 0 , --  batch: 17 / 1875 ,    Train loss: 1.449, accumulated average loss: 1.877 ##############################
# ########################### Epoch: 0 , --  batch: 18 / 1875 ,    Train loss: 1.303, accumulated average loss: 1.847 ##############################
# ########################### Epoch: 0 , --  batch: 19 / 1875 ,    Train loss: 1.316, accumulated average loss: 1.820 ##############################
# ########################### Epoch: 0 , --  batch: 20 / 1875 ,    Train loss: 1.195, accumulated average loss: 1.791 ##############################
# ########################### Epoch: 0 , --  batch: 21 / 1875 ,    Train loss: 1.190, accumulated average loss: 1.763 ##############################
# ########################### Epoch: 0 , --  batch: 22 / 1875 ,    Train loss: 1.371, accumulated average loss: 1.746 ##############################
# ########################### Epoch: 0 , --  batch: 23 / 1875 ,    Train loss: 1.422, accumulated average loss: 1.733 ##############################
# ########################### Epoch: 0 , --  batch: 24 / 1875 ,    Train loss: 1.312, accumulated average loss: 1.716 ##############################
# ########################### Epoch: 0 , --  batch: 25 / 1875 ,    Train loss: 1.016, accumulated average loss: 1.689 ##############################
# ########################### Epoch: 0 , --  batch: 26 / 1875 ,    Train loss: 1.316, accumulated average loss: 1.675 ##############################
# ########################### Epoch: 0 , --  batch: 27 / 1875 ,    Train loss: 1.223, accumulated average loss: 1.659 ##############################
# ########################### Epoch: 0 , --  batch: 28 / 1875 ,    Train loss: 1.165, accumulated average loss: 1.642 ##############################
# ########################### Epoch: 0 , --  batch: 29 / 1875 ,    Train loss: 1.154, accumulated average loss: 1.626 ##############################
# ########################### Epoch: 0 , --  batch: 30 / 1875 ,    Train loss: 0.937, accumulated average loss: 1.604 ##############################
# ########################### Epoch: 0 , --  batch: 31 / 1875 ,    Train loss: 1.109, accumulated average loss: 1.588 ##############################
# ########################### Epoch: 0 , --  batch: 32 / 1875 ,    Train loss: 0.861, accumulated average loss: 1.566 ##############################
# ########################### Epoch: 0 , --  batch: 33 / 1875 ,    Train loss: 1.068, accumulated average loss: 1.551 ##############################
# ########################### Epoch: 0 , --  batch: 34 / 1875 ,    Train loss: 1.119, accumulated average loss: 1.539 ##############################
# ########################### Epoch: 0 , --  batch: 35 / 1875 ,    Train loss: 0.981, accumulated average loss: 1.524 ##############################
# ########################### Epoch: 0 , --  batch: 36 / 1875 ,    Train loss: 1.104, accumulated average loss: 1.512 ##############################
# ########################### Epoch: 0 , --  batch: 37 / 1875 ,    Train loss: 0.835, accumulated average loss: 1.494 ##############################
# ########################### Epoch: 0 , --  batch: 38 / 1875 ,    Train loss: 1.032, accumulated average loss: 1.483 ##############################
# ########################### Epoch: 0 , --  batch: 39 / 1875 ,    Train loss: 0.757, accumulated average loss: 1.464 ##############################
# ########################### Epoch: 0 , --  batch: 40 / 1875 ,    Train loss: 0.850, accumulated average loss: 1.449 ##############################
# ########################### Epoch: 0 , --  batch: 41 / 1875 ,    Train loss: 0.590, accumulated average loss: 1.429 ##############################
# ########################### Epoch: 0 , --  batch: 42 / 1875 ,    Train loss: 0.746, accumulated average loss: 1.413 ##############################
# ########################### Epoch: 0 , --  batch: 43 / 1875 ,    Train loss: 0.807, accumulated average loss: 1.399 ##############################
# ########################### Epoch: 0 , --  batch: 44 / 1875 ,    Train loss: 0.777, accumulated average loss: 1.385 ##############################
# ########################### Epoch: 0 , --  batch: 45 / 1875 ,    Train loss: 0.814, accumulated average loss: 1.373 ##############################
# ########################### Epoch: 0 , --  batch: 46 / 1875 ,    Train loss: 0.813, accumulated average loss: 1.361 ##############################
# ########################### Epoch: 0 , --  batch: 47 / 1875 ,    Train loss: 0.656, accumulated average loss: 1.346 ##############################
# ########################### Epoch: 0 , --  batch: 48 / 1875 ,    Train loss: 1.005, accumulated average loss: 1.339 ##############################
# ########################### Epoch: 0 , --  batch: 49 / 1875 ,    Train loss: 0.717, accumulated average loss: 1.327 ##############################
# ########################### Epoch: 0 , --  batch: 50 / 1875 ,    Train loss: 0.950, accumulated average loss: 1.320 ##############################
# ########################### Epoch: 0 , --  batch: 51 / 1875 ,    Train loss: 0.842, accumulated average loss: 1.310 ##############################
# ########################### Epoch: 0 , --  batch: 52 / 1875 ,    Train loss: 0.638, accumulated average loss: 1.298 ##############################
# ########################### Epoch: 0 , --  batch: 53 / 1875 ,    Train loss: 0.716, accumulated average loss: 1.287 ##############################
# ########################### Epoch: 0 , --  batch: 54 / 1875 ,    Train loss: 0.718, accumulated average loss: 1.277 ##############################
# ########################### Epoch: 0 , --  batch: 55 / 1875 ,    Train loss: 0.738, accumulated average loss: 1.267 ##############################
# ########################### Epoch: 0 , --  batch: 56 / 1875 ,    Train loss: 0.977, accumulated average loss: 1.262 ##############################
# ########################### Epoch: 0 , --  batch: 57 / 1875 ,    Train loss: 1.046, accumulated average loss: 1.258 ##############################
# ########################### Epoch: 0 , --  batch: 58 / 1875 ,    Train loss: 0.656, accumulated average loss: 1.248 ##############################
# ########################### Epoch: 0 , --  batch: 59 / 1875 ,    Train loss: 0.928, accumulated average loss: 1.243 ##############################
# ########################### Epoch: 0 , --  batch: 60 / 1875 ,    Train loss: 0.779, accumulated average loss: 1.235 ##############################
# ########################### Epoch: 0 , --  batch: 61 / 1875 ,    Train loss: 0.716, accumulated average loss: 1.227 ##############################
# ########################### Epoch: 0 , --  batch: 62 / 1875 ,    Train loss: 0.462, accumulated average loss: 1.215 ##############################
# ########################### Epoch: 0 , --  batch: 63 / 1875 ,    Train loss: 0.451, accumulated average loss: 1.203 ##############################
# ########################### Epoch: 0 , --  batch: 64 / 1875 ,    Train loss: 0.699, accumulated average loss: 1.195 ##############################
# ########################### Epoch: 0 , --  batch: 65 / 1875 ,    Train loss: 0.690, accumulated average loss: 1.187 ##############################
# ########################### Epoch: 0 , --  batch: 66 / 1875 ,    Train loss: 0.663, accumulated average loss: 1.179 ##############################
# ########################### Epoch: 0 , --  batch: 67 / 1875 ,    Train loss: 0.868, accumulated average loss: 1.175 ##############################
# ########################### Epoch: 0 , --  batch: 68 / 1875 ,    Train loss: 0.934, accumulated average loss: 1.171 ##############################
# ########################### Epoch: 0 , --  batch: 69 / 1875 ,    Train loss: 0.842, accumulated average loss: 1.167 ##############################
# ########################### Epoch: 0 , --  batch: 70 / 1875 ,    Train loss: 0.634, accumulated average loss: 1.159 ##############################
# ########################### Epoch: 0 , --  batch: 71 / 1875 ,    Train loss: 0.523, accumulated average loss: 1.150 ##############################
# ########################### Epoch: 0 , --  batch: 72 / 1875 ,    Train loss: 0.689, accumulated average loss: 1.144 ##############################
# ########################### Epoch: 0 , --  batch: 73 / 1875 ,    Train loss: 0.774, accumulated average loss: 1.139 ##############################
# ########################### Epoch: 0 , --  batch: 74 / 1875 ,    Train loss: 0.529, accumulated average loss: 1.131 ##############################
# ########################### Epoch: 0 , --  batch: 75 / 1875 ,    Train loss: 0.490, accumulated average loss: 1.122 ##############################
# ########################### Epoch: 0 , --  batch: 76 / 1875 ,    Train loss: 0.544, accumulated average loss: 1.115 ##############################
# ########################### Epoch: 0 , --  batch: 77 / 1875 ,    Train loss: 0.755, accumulated average loss: 1.110 ##############################
# ########################### Epoch: 0 , --  batch: 78 / 1875 ,    Train loss: 0.312, accumulated average loss: 1.100 ##############################
# ########################### Epoch: 0 , --  batch: 79 / 1875 ,    Train loss: 0.712, accumulated average loss: 1.095 ##############################
# ########################### Epoch: 0 , --  batch: 80 / 1875 ,    Train loss: 0.748, accumulated average loss: 1.091 ##############################
# ########################### Epoch: 0 , --  batch: 81 / 1875 ,    Train loss: 0.602, accumulated average loss: 1.085 ##############################
# ########################### Epoch: 0 , --  batch: 82 / 1875 ,    Train loss: 0.989, accumulated average loss: 1.084 ##############################
# ########################### Epoch: 0 , --  batch: 83 / 1875 ,    Train loss: 0.566, accumulated average loss: 1.078 ##############################
# ########################### Epoch: 0 , --  batch: 84 / 1875 ,    Train loss: 1.050, accumulated average loss: 1.077 ##############################
# ########################### Epoch: 0 , --  batch: 85 / 1875 ,    Train loss: 0.638, accumulated average loss: 1.072 ##############################
# ########################### Epoch: 0 , --  batch: 86 / 1875 ,    Train loss: 0.573, accumulated average loss: 1.067 ##############################
# ########################### Epoch: 0 , --  batch: 87 / 1875 ,    Train loss: 0.660, accumulated average loss: 1.062 ##############################
# ########################### Epoch: 0 , --  batch: 88 / 1875 ,    Train loss: 0.549, accumulated average loss: 1.056 ##############################
# ########################### Epoch: 0 , --  batch: 89 / 1875 ,    Train loss: 0.835, accumulated average loss: 1.054 ##############################
# ########################### Epoch: 0 , --  batch: 90 / 1875 ,    Train loss: 0.650, accumulated average loss: 1.049 ##############################
# ########################### Epoch: 0 , --  batch: 91 / 1875 ,    Train loss: 0.695, accumulated average loss: 1.045 ##############################
# ########################### Epoch: 0 , --  batch: 92 / 1875 ,    Train loss: 0.629, accumulated average loss: 1.041 ##############################
# ########################### Epoch: 0 , --  batch: 93 / 1875 ,    Train loss: 0.771, accumulated average loss: 1.038 ##############################
# ########################### Epoch: 0 , --  batch: 94 / 1875 ,    Train loss: 0.467, accumulated average loss: 1.032 ##############################
# ########################### Epoch: 0 , --  batch: 95 / 1875 ,    Train loss: 0.451, accumulated average loss: 1.026 ##############################
# ########################### Epoch: 0 , --  batch: 96 / 1875 ,    Train loss: 0.596, accumulated average loss: 1.022 ##############################
# ########################### Epoch: 0 , --  batch: 97 / 1875 ,    Train loss: 0.630, accumulated average loss: 1.018 ##############################
# ########################### Epoch: 0 , --  batch: 98 / 1875 ,    Train loss: 0.613, accumulated average loss: 1.013 ##############################
# ########################### Epoch: 0 , --  batch: 99 / 1875 ,    Train loss: 0.655, accumulated average loss: 1.010 ##############################
# ########################### Epoch: 0 , --  batch: 100 / 1875 ,    Train loss: 0.902, accumulated average loss: 1.009 ##############################
# ########################### Epoch: 0 , --  batch: 101 / 1875 ,    Train loss: 0.489, accumulated average loss: 1.004 ##############################
# ########################### Epoch: 0 , --  batch: 102 / 1875 ,    Train loss: 0.600, accumulated average loss: 1.000 ##############################
# ########################### Epoch: 0 , --  batch: 103 / 1875 ,    Train loss: 0.501, accumulated average loss: 0.995 ##############################
# ########################### Epoch: 0 , --  batch: 104 / 1875 ,    Train loss: 0.473, accumulated average loss: 0.990 ##############################
# ########################### Epoch: 0 , --  batch: 105 / 1875 ,    Train loss: 0.383, accumulated average loss: 0.984 ##############################
# ########################### Epoch: 0 , --  batch: 106 / 1875 ,    Train loss: 0.406, accumulated average loss: 0.979 ##############################
# ########################### Epoch: 0 , --  batch: 107 / 1875 ,    Train loss: 0.604, accumulated average loss: 0.975 ##############################
# ########################### Epoch: 0 , --  batch: 108 / 1875 ,    Train loss: 0.609, accumulated average loss: 0.972 ##############################
# ########################### Epoch: 0 , --  batch: 109 / 1875 ,    Train loss: 0.812, accumulated average loss: 0.971 ##############################
# ########################### Epoch: 0 , --  batch: 110 / 1875 ,    Train loss: 0.675, accumulated average loss: 0.968 ##############################
# ########################### Epoch: 0 , --  batch: 111 / 1875 ,    Train loss: 0.516, accumulated average loss: 0.964 ##############################
# ########################### Epoch: 0 , --  batch: 112 / 1875 ,    Train loss: 0.840, accumulated average loss: 0.963 ##############################
# ########################### Epoch: 0 , --  batch: 113 / 1875 ,    Train loss: 0.464, accumulated average loss: 0.958 ##############################
# ########################### Epoch: 0 , --  batch: 114 / 1875 ,    Train loss: 0.544, accumulated average loss: 0.955 ##############################
# ########################### Epoch: 0 , --  batch: 115 / 1875 ,    Train loss: 0.466, accumulated average loss: 0.951 ##############################
# ########################### Epoch: 0 , --  batch: 116 / 1875 ,    Train loss: 0.417, accumulated average loss: 0.946 ##############################
# ########################### Epoch: 0 , --  batch: 117 / 1875 ,    Train loss: 0.792, accumulated average loss: 0.945 ##############################
# ########################### Epoch: 0 , --  batch: 118 / 1875 ,    Train loss: 0.368, accumulated average loss: 0.940 ##############################
# ########################### Epoch: 0 , --  batch: 119 / 1875 ,    Train loss: 0.363, accumulated average loss: 0.935 ##############################
# ########################### Epoch: 0 , --  batch: 120 / 1875 ,    Train loss: 0.347, accumulated average loss: 0.930 ##############################
# ########################### Epoch: 0 , --  batch: 121 / 1875 ,    Train loss: 0.769, accumulated average loss: 0.929 ##############################
# ########################### Epoch: 0 , --  batch: 122 / 1875 ,    Train loss: 0.739, accumulated average loss: 0.927 ##############################
# ########################### Epoch: 0 , --  batch: 123 / 1875 ,    Train loss: 0.322, accumulated average loss: 0.923 ##############################
# ########################### Epoch: 0 , --  batch: 124 / 1875 ,    Train loss: 0.835, accumulated average loss: 0.922 ##############################
# ########################### Epoch: 0 , --  batch: 125 / 1875 ,    Train loss: 0.297, accumulated average loss: 0.917 ##############################
# ########################### Epoch: 0 , --  batch: 126 / 1875 ,    Train loss: 0.616, accumulated average loss: 0.914 ##############################
# ########################### Epoch: 0 , --  batch: 127 / 1875 ,    Train loss: 0.641, accumulated average loss: 0.912 ##############################
# ########################### Epoch: 0 , --  batch: 128 / 1875 ,    Train loss: 0.349, accumulated average loss: 0.908 ##############################
# ########################### Epoch: 0 , --  batch: 129 / 1875 ,    Train loss: 0.305, accumulated average loss: 0.903 ##############################
# ########################### Epoch: 0 , --  batch: 130 / 1875 ,    Train loss: 0.495, accumulated average loss: 0.900 ##############################
# ########################### Epoch: 0 , --  batch: 131 / 1875 ,    Train loss: 0.431, accumulated average loss: 0.897 ##############################
# ########################### Epoch: 0 , --  batch: 132 / 1875 ,    Train loss: 0.822, accumulated average loss: 0.896 ##############################
# ########################### Epoch: 0 , --  batch: 133 / 1875 ,    Train loss: 0.692, accumulated average loss: 0.895 ##############################
# ########################### Epoch: 0 , --  batch: 134 / 1875 ,    Train loss: 0.445, accumulated average loss: 0.891 ##############################
# ########################### Epoch: 0 , --  batch: 135 / 1875 ,    Train loss: 0.437, accumulated average loss: 0.888 ##############################
# ########################### Epoch: 0 , --  batch: 136 / 1875 ,    Train loss: 0.661, accumulated average loss: 0.886 ##############################
# ########################### Epoch: 0 , --  batch: 137 / 1875 ,    Train loss: 0.454, accumulated average loss: 0.883 ##############################
# ########################### Epoch: 0 , --  batch: 138 / 1875 ,    Train loss: 0.377, accumulated average loss: 0.879 ##############################
# ########################### Epoch: 0 , --  batch: 139 / 1875 ,    Train loss: 0.283, accumulated average loss: 0.875 ##############################
# ########################### Epoch: 0 , --  batch: 140 / 1875 ,    Train loss: 0.508, accumulated average loss: 0.873 ##############################
# ########################### Epoch: 0 , --  batch: 141 / 1875 ,    Train loss: 0.447, accumulated average loss: 0.870 ##############################
# ########################### Epoch: 0 , --  batch: 142 / 1875 ,    Train loss: 0.342, accumulated average loss: 0.866 ##############################
# ########################### Epoch: 0 , --  batch: 143 / 1875 ,    Train loss: 0.219, accumulated average loss: 0.861 ##############################
# ########################### Epoch: 0 , --  batch: 144 / 1875 ,    Train loss: 0.525, accumulated average loss: 0.859 ##############################
# ########################### Epoch: 0 , --  batch: 145 / 1875 ,    Train loss: 0.705, accumulated average loss: 0.858 ##############################
# ########################### Epoch: 0 , --  batch: 146 / 1875 ,    Train loss: 0.387, accumulated average loss: 0.855 ##############################
# ########################### Epoch: 0 , --  batch: 147 / 1875 ,    Train loss: 0.348, accumulated average loss: 0.851 ##############################
# ########################### Epoch: 0 , --  batch: 148 / 1875 ,    Train loss: 0.981, accumulated average loss: 0.852 ##############################
# ########################### Epoch: 0 , --  batch: 149 / 1875 ,    Train loss: 0.600, accumulated average loss: 0.851 ##############################
# ########################### Epoch: 0 , --  batch: 150 / 1875 ,    Train loss: 0.615, accumulated average loss: 0.849 ##############################
# ########################### Epoch: 0 , --  batch: 151 / 1875 ,    Train loss: 0.327, accumulated average loss: 0.846 ##############################
# ########################### Epoch: 0 , --  batch: 152 / 1875 ,    Train loss: 0.609, accumulated average loss: 0.844 ##############################
# ########################### Epoch: 0 , --  batch: 153 / 1875 ,    Train loss: 0.365, accumulated average loss: 0.841 ##############################
# ########################### Epoch: 0 , --  batch: 154 / 1875 ,    Train loss: 0.415, accumulated average loss: 0.838 ##############################
# ########################### Epoch: 0 , --  batch: 155 / 1875 ,    Train loss: 0.567, accumulated average loss: 0.836 ##############################
# ########################### Epoch: 0 , --  batch: 156 / 1875 ,    Train loss: 0.856, accumulated average loss: 0.837 ##############################
# ########################### Epoch: 0 , --  batch: 157 / 1875 ,    Train loss: 0.996, accumulated average loss: 0.838 ##############################
# ########################### Epoch: 0 , --  batch: 158 / 1875 ,    Train loss: 0.188, accumulated average loss: 0.834 ##############################
# ########################### Epoch: 0 , --  batch: 159 / 1875 ,    Train loss: 0.398, accumulated average loss: 0.831 ##############################
# ########################### Epoch: 0 , --  batch: 160 / 1875 ,    Train loss: 0.631, accumulated average loss: 0.830 ##############################
# ########################### Epoch: 0 , --  batch: 161 / 1875 ,    Train loss: 0.697, accumulated average loss: 0.829 ##############################
# ########################### Epoch: 0 , --  batch: 162 / 1875 ,    Train loss: 0.372, accumulated average loss: 0.826 ##############################
# ########################### Epoch: 0 , --  batch: 163 / 1875 ,    Train loss: 0.635, accumulated average loss: 0.825 ##############################
# ########################### Epoch: 0 , --  batch: 164 / 1875 ,    Train loss: 0.441, accumulated average loss: 0.822 ##############################
# ########################### Epoch: 0 , --  batch: 165 / 1875 ,    Train loss: 0.497, accumulated average loss: 0.820 ##############################
# ########################### Epoch: 0 , --  batch: 166 / 1875 ,    Train loss: 0.426, accumulated average loss: 0.818 ##############################
# ########################### Epoch: 0 , --  batch: 167 / 1875 ,    Train loss: 0.437, accumulated average loss: 0.816 ##############################
# ########################### Epoch: 0 , --  batch: 168 / 1875 ,    Train loss: 0.464, accumulated average loss: 0.814 ##############################
# ########################### Epoch: 0 , --  batch: 169 / 1875 ,    Train loss: 0.815, accumulated average loss: 0.814 ##############################
# ########################### Epoch: 0 , --  batch: 170 / 1875 ,    Train loss: 0.507, accumulated average loss: 0.812 ##############################
# ########################### Epoch: 0 , --  batch: 171 / 1875 ,    Train loss: 0.434, accumulated average loss: 0.810 ##############################
# ########################### Epoch: 0 , --  batch: 172 / 1875 ,    Train loss: 0.425, accumulated average loss: 0.808 ##############################
# ########################### Epoch: 0 , --  batch: 173 / 1875 ,    Train loss: 0.589, accumulated average loss: 0.806 ##############################
# ########################### Epoch: 0 , --  batch: 174 / 1875 ,    Train loss: 0.549, accumulated average loss: 0.805 ##############################
# ########################### Epoch: 0 , --  batch: 175 / 1875 ,    Train loss: 0.505, accumulated average loss: 0.803 ##############################
# ########################### Epoch: 0 , --  batch: 176 / 1875 ,    Train loss: 0.743, accumulated average loss: 0.803 ##############################
# ########################### Epoch: 0 , --  batch: 177 / 1875 ,    Train loss: 0.435, accumulated average loss: 0.801 ##############################
# ########################### Epoch: 0 , --  batch: 178 / 1875 ,    Train loss: 0.399, accumulated average loss: 0.798 ##############################
# ########################### Epoch: 0 , --  batch: 179 / 1875 ,    Train loss: 0.434, accumulated average loss: 0.796 ##############################
# ########################### Epoch: 0 , --  batch: 180 / 1875 ,    Train loss: 0.461, accumulated average loss: 0.795 ##############################
# ########################### Epoch: 0 , --  batch: 181 / 1875 ,    Train loss: 0.600, accumulated average loss: 0.794 ##############################
# ########################### Epoch: 0 , --  batch: 182 / 1875 ,    Train loss: 0.832, accumulated average loss: 0.794 ##############################
# ########################### Epoch: 0 , --  batch: 183 / 1875 ,    Train loss: 0.445, accumulated average loss: 0.792 ##############################
# ########################### Epoch: 0 , --  batch: 184 / 1875 ,    Train loss: 0.451, accumulated average loss: 0.790 ##############################
# ########################### Epoch: 0 , --  batch: 185 / 1875 ,    Train loss: 0.396, accumulated average loss: 0.788 ##############################
# ########################### Epoch: 0 , --  batch: 186 / 1875 ,    Train loss: 0.593, accumulated average loss: 0.787 ##############################
# ########################### Epoch: 0 , --  batch: 187 / 1875 ,    Train loss: 0.751, accumulated average loss: 0.787 ##############################
# ########################### Epoch: 0 , --  batch: 188 / 1875 ,    Train loss: 0.365, accumulated average loss: 0.784 ##############################
# ########################### Epoch: 0 , --  batch: 189 / 1875 ,    Train loss: 0.434, accumulated average loss: 0.783 ##############################
# ########################### Epoch: 0 , --  batch: 190 / 1875 ,    Train loss: 0.612, accumulated average loss: 0.782 ##############################
# ########################### Epoch: 0 , --  batch: 191 / 1875 ,    Train loss: 0.338, accumulated average loss: 0.779 ##############################
# ########################### Epoch: 0 , --  batch: 192 / 1875 ,    Train loss: 0.906, accumulated average loss: 0.780 ##############################
# ########################### Epoch: 0 , --  batch: 193 / 1875 ,    Train loss: 0.493, accumulated average loss: 0.779 ##############################
# ########################### Epoch: 0 , --  batch: 194 / 1875 ,    Train loss: 0.526, accumulated average loss: 0.777 ##############################
# ########################### Epoch: 0 , --  batch: 195 / 1875 ,    Train loss: 0.516, accumulated average loss: 0.776 ##############################
# ########################### Epoch: 0 , --  batch: 196 / 1875 ,    Train loss: 0.723, accumulated average loss: 0.776 ##############################
# ########################### Epoch: 0 , --  batch: 197 / 1875 ,    Train loss: 0.655, accumulated average loss: 0.775 ##############################
# ########################### Epoch: 0 , --  batch: 198 / 1875 ,    Train loss: 0.353, accumulated average loss: 0.773 ##############################
# ########################### Epoch: 0 , --  batch: 199 / 1875 ,    Train loss: 0.655, accumulated average loss: 0.772 ##############################
# ########################### Epoch: 0 , --  batch: 200 / 1875 ,    Train loss: 0.369, accumulated average loss: 0.770 ##############################
# ########################### Epoch: 0 , --  batch: 201 / 1875 ,    Train loss: 0.402, accumulated average loss: 0.768 ##############################
# ########################### Epoch: 0 , --  batch: 202 / 1875 ,    Train loss: 0.476, accumulated average loss: 0.767 ##############################
# ########################### Epoch: 0 , --  batch: 203 / 1875 ,    Train loss: 0.719, accumulated average loss: 0.767 ##############################
# ########################### Epoch: 0 , --  batch: 204 / 1875 ,    Train loss: 0.392, accumulated average loss: 0.765 ##############################
# ########################### Epoch: 0 , --  batch: 205 / 1875 ,    Train loss: 0.563, accumulated average loss: 0.764 ##############################
# ########################### Epoch: 0 , --  batch: 206 / 1875 ,    Train loss: 0.430, accumulated average loss: 0.762 ##############################
# ########################### Epoch: 0 , --  batch: 207 / 1875 ,    Train loss: 0.450, accumulated average loss: 0.761 ##############################
# ########################### Epoch: 0 , --  batch: 208 / 1875 ,    Train loss: 0.636, accumulated average loss: 0.760 ##############################
# ########################### Epoch: 0 , --  batch: 209 / 1875 ,    Train loss: 0.736, accumulated average loss: 0.760 ##############################
# ########################### Epoch: 0 , --  batch: 210 / 1875 ,    Train loss: 0.357, accumulated average loss: 0.758 ##############################
# ########################### Epoch: 0 , --  batch: 211 / 1875 ,    Train loss: 0.439, accumulated average loss: 0.757 ##############################
# ########################### Epoch: 0 , --  batch: 212 / 1875 ,    Train loss: 0.376, accumulated average loss: 0.755 ##############################
# ########################### Epoch: 0 , --  batch: 213 / 1875 ,    Train loss: 0.566, accumulated average loss: 0.754 ##############################
# ########################### Epoch: 0 , --  batch: 214 / 1875 ,    Train loss: 0.525, accumulated average loss: 0.753 ##############################
# ########################### Epoch: 0 , --  batch: 215 / 1875 ,    Train loss: 0.362, accumulated average loss: 0.751 ##############################
# ########################### Epoch: 0 , --  batch: 216 / 1875 ,    Train loss: 0.418, accumulated average loss: 0.750 ##############################
# ########################### Epoch: 0 , --  batch: 217 / 1875 ,    Train loss: 0.673, accumulated average loss: 0.749 ##############################
# ########################### Epoch: 0 , --  batch: 218 / 1875 ,    Train loss: 0.259, accumulated average loss: 0.747 ##############################
# ########################### Epoch: 0 , --  batch: 219 / 1875 ,    Train loss: 0.697, accumulated average loss: 0.747 ##############################
# ########################### Epoch: 0 , --  batch: 220 / 1875 ,    Train loss: 0.484, accumulated average loss: 0.746 ##############################
# ########################### Epoch: 0 , --  batch: 221 / 1875 ,    Train loss: 0.690, accumulated average loss: 0.745 ##############################
# ########################### Epoch: 0 , --  batch: 222 / 1875 ,    Train loss: 0.583, accumulated average loss: 0.745 ##############################
# ########################### Epoch: 0 , --  batch: 223 / 1875 ,    Train loss: 0.689, accumulated average loss: 0.744 ##############################
# ########################### Epoch: 0 , --  batch: 224 / 1875 ,    Train loss: 0.370, accumulated average loss: 0.743 ##############################
# ########################### Epoch: 0 , --  batch: 225 / 1875 ,    Train loss: 0.392, accumulated average loss: 0.741 ##############################
# ########################### Epoch: 0 , --  batch: 226 / 1875 ,    Train loss: 0.394, accumulated average loss: 0.740 ##############################
# ########################### Epoch: 0 , --  batch: 227 / 1875 ,    Train loss: 0.181, accumulated average loss: 0.737 ##############################
# ########################### Epoch: 0 , --  batch: 228 / 1875 ,    Train loss: 0.491, accumulated average loss: 0.736 ##############################
# ########################### Epoch: 0 , --  batch: 229 / 1875 ,    Train loss: 0.318, accumulated average loss: 0.734 ##############################
# ########################### Epoch: 0 , --  batch: 230 / 1875 ,    Train loss: 0.688, accumulated average loss: 0.734 ##############################
# ########################### Epoch: 0 , --  batch: 231 / 1875 ,    Train loss: 0.662, accumulated average loss: 0.734 ##############################
# ########################### Epoch: 0 , --  batch: 232 / 1875 ,    Train loss: 0.293, accumulated average loss: 0.732 ##############################
# ########################### Epoch: 0 , --  batch: 233 / 1875 ,    Train loss: 0.323, accumulated average loss: 0.730 ##############################
# ########################### Epoch: 0 , --  batch: 234 / 1875 ,    Train loss: 0.353, accumulated average loss: 0.729 ##############################
# ########################### Epoch: 0 , --  batch: 235 / 1875 ,    Train loss: 0.339, accumulated average loss: 0.727 ##############################
# ########################### Epoch: 0 , --  batch: 236 / 1875 ,    Train loss: 0.547, accumulated average loss: 0.726 ##############################
# ########################### Epoch: 0 , --  batch: 237 / 1875 ,    Train loss: 0.373, accumulated average loss: 0.725 ##############################
# ########################### Epoch: 0 , --  batch: 238 / 1875 ,    Train loss: 0.858, accumulated average loss: 0.725 ##############################
# ########################### Epoch: 0 , --  batch: 239 / 1875 ,    Train loss: 0.568, accumulated average loss: 0.725 ##############################
# ########################### Epoch: 0 , --  batch: 240 / 1875 ,    Train loss: 0.259, accumulated average loss: 0.723 ##############################
# ########################### Epoch: 0 , --  batch: 241 / 1875 ,    Train loss: 0.660, accumulated average loss: 0.722 ##############################
# ########################### Epoch: 0 , --  batch: 242 / 1875 ,    Train loss: 0.453, accumulated average loss: 0.721 ##############################
# ########################### Epoch: 0 , --  batch: 243 / 1875 ,    Train loss: 0.320, accumulated average loss: 0.720 ##############################
# ########################### Epoch: 0 , --  batch: 244 / 1875 ,    Train loss: 0.517, accumulated average loss: 0.719 ##############################
# ########################### Epoch: 0 , --  batch: 245 / 1875 ,    Train loss: 0.288, accumulated average loss: 0.717 ##############################
# ########################### Epoch: 0 , --  batch: 246 / 1875 ,    Train loss: 0.376, accumulated average loss: 0.716 ##############################
# ########################### Epoch: 0 , --  batch: 247 / 1875 ,    Train loss: 0.370, accumulated average loss: 0.714 ##############################
# ########################### Epoch: 0 , --  batch: 248 / 1875 ,    Train loss: 0.509, accumulated average loss: 0.713 ##############################
# ########################### Epoch: 0 , --  batch: 249 / 1875 ,    Train loss: 0.668, accumulated average loss: 0.713 ##############################
# ########################### Epoch: 0 , --  batch: 250 / 1875 ,    Train loss: 0.538, accumulated average loss: 0.713 ##############################
# ########################### Epoch: 0 , --  batch: 251 / 1875 ,    Train loss: 0.289, accumulated average loss: 0.711 ##############################
# ########################### Epoch: 0 , --  batch: 252 / 1875 ,    Train loss: 0.481, accumulated average loss: 0.710 ##############################
# ########################### Epoch: 0 , --  batch: 253 / 1875 ,    Train loss: 0.616, accumulated average loss: 0.710 ##############################
# ########################### Epoch: 0 , --  batch: 254 / 1875 ,    Train loss: 0.433, accumulated average loss: 0.709 ##############################
# ########################### Epoch: 0 , --  batch: 255 / 1875 ,    Train loss: 0.461, accumulated average loss: 0.708 ##############################
# ########################### Epoch: 0 , --  batch: 256 / 1875 ,    Train loss: 0.280, accumulated average loss: 0.706 ##############################
# ########################### Epoch: 0 , --  batch: 257 / 1875 ,    Train loss: 0.536, accumulated average loss: 0.705 ##############################
# ########################### Epoch: 0 , --  batch: 258 / 1875 ,    Train loss: 0.685, accumulated average loss: 0.705 ##############################
# ########################### Epoch: 0 , --  batch: 259 / 1875 ,    Train loss: 0.387, accumulated average loss: 0.704 ##############################
# ########################### Epoch: 0 , --  batch: 260 / 1875 ,    Train loss: 0.195, accumulated average loss: 0.702 ##############################
# ########################### Epoch: 0 , --  batch: 261 / 1875 ,    Train loss: 0.371, accumulated average loss: 0.701 ##############################
# ########################### Epoch: 0 , --  batch: 262 / 1875 ,    Train loss: 0.507, accumulated average loss: 0.700 ##############################
# ########################### Epoch: 0 , --  batch: 263 / 1875 ,    Train loss: 0.576, accumulated average loss: 0.700 ##############################
# ########################### Epoch: 0 , --  batch: 264 / 1875 ,    Train loss: 0.426, accumulated average loss: 0.699 ##############################
# ########################### Epoch: 0 , --  batch: 265 / 1875 ,    Train loss: 0.593, accumulated average loss: 0.698 ##############################
# ########################### Epoch: 0 , --  batch: 266 / 1875 ,    Train loss: 0.332, accumulated average loss: 0.697 ##############################
# ########################### Epoch: 0 , --  batch: 267 / 1875 ,    Train loss: 0.313, accumulated average loss: 0.695 ##############################
# ########################### Epoch: 0 , --  batch: 268 / 1875 ,    Train loss: 0.477, accumulated average loss: 0.695 ##############################
# ########################### Epoch: 0 , --  batch: 269 / 1875 ,    Train loss: 0.621, accumulated average loss: 0.694 ##############################
# ########################### Epoch: 0 , --  batch: 270 / 1875 ,    Train loss: 0.312, accumulated average loss: 0.693 ##############################
# ########################### Epoch: 0 , --  batch: 271 / 1875 ,    Train loss: 0.765, accumulated average loss: 0.693 ##############################
# ########################### Epoch: 0 , --  batch: 272 / 1875 ,    Train loss: 0.210, accumulated average loss: 0.691 ##############################
# ########################### Epoch: 0 , --  batch: 273 / 1875 ,    Train loss: 0.166, accumulated average loss: 0.689 ##############################
# ########################### Epoch: 0 , --  batch: 274 / 1875 ,    Train loss: 0.582, accumulated average loss: 0.689 ##############################
# ########################### Epoch: 0 , --  batch: 275 / 1875 ,    Train loss: 0.343, accumulated average loss: 0.688 ##############################
# ########################### Epoch: 0 , --  batch: 276 / 1875 ,    Train loss: 0.309, accumulated average loss: 0.686 ##############################
# ########################### Epoch: 0 , --  batch: 277 / 1875 ,    Train loss: 0.385, accumulated average loss: 0.685 ##############################
# ########################### Epoch: 0 , --  batch: 278 / 1875 ,    Train loss: 0.198, accumulated average loss: 0.684 ##############################
# ########################### Epoch: 0 , --  batch: 279 / 1875 ,    Train loss: 0.783, accumulated average loss: 0.684 ##############################
# ########################### Epoch: 0 , --  batch: 280 / 1875 ,    Train loss: 0.852, accumulated average loss: 0.685 ##############################
# ########################### Epoch: 0 , --  batch: 281 / 1875 ,    Train loss: 0.246, accumulated average loss: 0.683 ##############################
# ########################### Epoch: 0 , --  batch: 282 / 1875 ,    Train loss: 0.296, accumulated average loss: 0.682 ##############################
# ########################### Epoch: 0 , --  batch: 283 / 1875 ,    Train loss: 0.701, accumulated average loss: 0.682 ##############################
# ########################### Epoch: 0 , --  batch: 284 / 1875 ,    Train loss: 0.540, accumulated average loss: 0.681 ##############################
# ########################### Epoch: 0 , --  batch: 285 / 1875 ,    Train loss: 0.530, accumulated average loss: 0.681 ##############################
# ########################### Epoch: 0 , --  batch: 286 / 1875 ,    Train loss: 0.598, accumulated average loss: 0.680 ##############################
# ########################### Epoch: 0 , --  batch: 287 / 1875 ,    Train loss: 0.285, accumulated average loss: 0.679 ##############################
# ########################### Epoch: 0 , --  batch: 288 / 1875 ,    Train loss: 0.412, accumulated average loss: 0.678 ##############################
# ########################### Epoch: 0 , --  batch: 289 / 1875 ,    Train loss: 0.634, accumulated average loss: 0.678 ##############################
# ########################### Epoch: 0 , --  batch: 290 / 1875 ,    Train loss: 0.278, accumulated average loss: 0.677 ##############################
# ########################### Epoch: 0 , --  batch: 291 / 1875 ,    Train loss: 0.416, accumulated average loss: 0.676 ##############################
# ########################### Epoch: 0 , --  batch: 292 / 1875 ,    Train loss: 0.944, accumulated average loss: 0.677 ##############################
# ########################### Epoch: 0 , --  batch: 293 / 1875 ,    Train loss: 0.630, accumulated average loss: 0.676 ##############################
# ########################### Epoch: 0 , --  batch: 294 / 1875 ,    Train loss: 0.443, accumulated average loss: 0.676 ##############################
# ########################### Epoch: 0 , --  batch: 295 / 1875 ,    Train loss: 0.383, accumulated average loss: 0.675 ##############################
# ########################### Epoch: 0 , --  batch: 296 / 1875 ,    Train loss: 0.503, accumulated average loss: 0.674 ##############################
# ########################### Epoch: 0 , --  batch: 297 / 1875 ,    Train loss: 0.589, accumulated average loss: 0.674 ##############################
# ########################### Epoch: 0 , --  batch: 298 / 1875 ,    Train loss: 0.369, accumulated average loss: 0.673 ##############################
# ########################### Epoch: 0 , --  batch: 299 / 1875 ,    Train loss: 0.394, accumulated average loss: 0.672 ##############################
# ########################### Epoch: 0 , --  batch: 300 / 1875 ,    Train loss: 0.418, accumulated average loss: 0.671 ##############################
# ########################### Epoch: 0 , --  batch: 301 / 1875 ,    Train loss: 0.333, accumulated average loss: 0.670 ##############################
# ########################### Epoch: 0 , --  batch: 302 / 1875 ,    Train loss: 0.711, accumulated average loss: 0.670 ##############################
# ########################### Epoch: 0 , --  batch: 303 / 1875 ,    Train loss: 0.413, accumulated average loss: 0.669 ##############################
# ########################### Epoch: 0 , --  batch: 304 / 1875 ,    Train loss: 0.511, accumulated average loss: 0.669 ##############################
# ########################### Epoch: 0 , --  batch: 305 / 1875 ,    Train loss: 0.313, accumulated average loss: 0.667 ##############################
# ########################### Epoch: 0 , --  batch: 306 / 1875 ,    Train loss: 0.369, accumulated average loss: 0.666 ##############################
# ########################### Epoch: 0 , --  batch: 307 / 1875 ,    Train loss: 0.264, accumulated average loss: 0.665 ##############################
# ########################### Epoch: 0 , --  batch: 308 / 1875 ,    Train loss: 0.305, accumulated average loss: 0.664 ##############################
# ########################### Epoch: 0 , --  batch: 309 / 1875 ,    Train loss: 0.090, accumulated average loss: 0.662 ##############################
# ########################### Epoch: 0 , --  batch: 310 / 1875 ,    Train loss: 0.409, accumulated average loss: 0.661 ##############################
# ########################### Epoch: 0 , --  batch: 311 / 1875 ,    Train loss: 0.624, accumulated average loss: 0.661 ##############################
# ########################### Epoch: 0 , --  batch: 312 / 1875 ,    Train loss: 0.047, accumulated average loss: 0.659 ##############################
# ########################### Epoch: 0 , --  batch: 313 / 1875 ,    Train loss: 0.435, accumulated average loss: 0.659 ##############################
# ########################### Epoch: 0 , --  batch: 314 / 1875 ,    Train loss: 0.360, accumulated average loss: 0.658 ##############################
# ########################### Epoch: 0 , --  batch: 315 / 1875 ,    Train loss: 0.533, accumulated average loss: 0.657 ##############################
# ########################### Epoch: 0 , --  batch: 316 / 1875 ,    Train loss: 0.518, accumulated average loss: 0.657 ##############################
# ########################### Epoch: 0 , --  batch: 317 / 1875 ,    Train loss: 0.528, accumulated average loss: 0.656 ##############################
# ########################### Epoch: 0 , --  batch: 318 / 1875 ,    Train loss: 0.328, accumulated average loss: 0.655 ##############################
# ########################### Epoch: 0 , --  batch: 319 / 1875 ,    Train loss: 0.541, accumulated average loss: 0.655 ##############################
# ########################### Epoch: 0 , --  batch: 320 / 1875 ,    Train loss: 0.637, accumulated average loss: 0.655 ##############################
# ########################### Epoch: 0 , --  batch: 321 / 1875 ,    Train loss: 0.430, accumulated average loss: 0.654 ##############################
# ########################### Epoch: 0 , --  batch: 322 / 1875 ,    Train loss: 0.131, accumulated average loss: 0.653 ##############################
# ########################### Epoch: 0 , --  batch: 323 / 1875 ,    Train loss: 0.317, accumulated average loss: 0.652 ##############################
# ...
# ########################### Epoch: 4 , --  batch: 204 / 313 ,    Test loss: 0.290, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 205 / 313 ,    Test loss: 0.036, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 206 / 313 ,    Test loss: 0.057, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 207 / 313 ,    Test loss: 0.264, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 208 / 313 ,    Test loss: 0.122, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 209 / 313 ,    Test loss: 0.005, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 210 / 313 ,    Test loss: 0.011, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 211 / 313 ,    Test loss: 0.008, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 212 / 313 ,    Test loss: 0.097, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 213 / 313 ,    Test loss: 0.033, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 214 / 313 ,    Test loss: 0.011, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 215 / 313 ,    Test loss: 0.017, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 216 / 313 ,    Test loss: 0.112, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 217 / 313 ,    Test loss: 0.176, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 218 / 313 ,    Test loss: 0.001, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 219 / 313 ,    Test loss: 0.043, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 220 / 313 ,    Test loss: 0.142, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 221 / 313 ,    Test loss: 0.013, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 222 / 313 ,    Test loss: 0.053, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 223 / 313 ,    Test loss: 0.329, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 224 / 313 ,    Test loss: 0.005, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 225 / 313 ,    Test loss: 0.021, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 226 / 313 ,    Test loss: 0.106, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 227 / 313 ,    Test loss: 0.455, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 228 / 313 ,    Test loss: 0.147, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 229 / 313 ,    Test loss: 0.316, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 230 / 313 ,    Test loss: 0.063, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 231 / 313 ,    Test loss: 0.065, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 232 / 313 ,    Test loss: 0.202, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 233 / 313 ,    Test loss: 0.009, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 234 / 313 ,    Test loss: 0.027, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 235 / 313 ,    Test loss: 0.006, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 236 / 313 ,    Test loss: 0.006, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 237 / 313 ,    Test loss: 0.047, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 238 / 313 ,    Test loss: 0.024, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 239 / 313 ,    Test loss: 0.328, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 240 / 313 ,    Test loss: 0.040, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 241 / 313 ,    Test loss: 0.019, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 242 / 313 ,    Test loss: 0.194, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 243 / 313 ,    Test loss: 0.028, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 244 / 313 ,    Test loss: 0.109, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 245 / 313 ,    Test loss: 0.002, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 246 / 313 ,    Test loss: 0.008, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 247 / 313 ,    Test loss: 0.083, accumulated average loss: 0.109 ##############################
# ########################### Epoch: 4 , --  batch: 248 / 313 ,    Test loss: 0.036, accumulated average loss: 0.109 ##############################
# ########################### Epoch: 4 , --  batch: 249 / 313 ,    Test loss: 0.438, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 250 / 313 ,    Test loss: 0.017, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 251 / 313 ,    Test loss: 0.050, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 252 / 313 ,    Test loss: 0.285, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 253 / 313 ,    Test loss: 0.001, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 254 / 313 ,    Test loss: 0.060, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 255 / 313 ,    Test loss: 0.203, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 256 / 313 ,    Test loss: 0.352, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 257 / 313 ,    Test loss: 0.132, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 258 / 313 ,    Test loss: 0.060, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 259 / 313 ,    Test loss: 0.073, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 260 / 313 ,    Test loss: 0.378, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 261 / 313 ,    Test loss: 0.012, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 262 / 313 ,    Test loss: 0.235, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 263 / 313 ,    Test loss: 0.078, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 264 / 313 ,    Test loss: 0.020, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 265 / 313 ,    Test loss: 0.051, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 266 / 313 ,    Test loss: 0.120, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 267 / 313 ,    Test loss: 0.001, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 268 / 313 ,    Test loss: 0.002, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 269 / 313 ,    Test loss: 0.012, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 270 / 313 ,    Test loss: 0.354, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 271 / 313 ,    Test loss: 0.023, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 272 / 313 ,    Test loss: 0.016, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 273 / 313 ,    Test loss: 0.173, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 274 / 313 ,    Test loss: 0.038, accumulated average loss: 0.110 ##############################
# ########################### Epoch: 4 , --  batch: 275 / 313 ,    Test loss: 0.237, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 276 / 313 ,    Test loss: 0.295, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 277 / 313 ,    Test loss: 0.116, accumulated average loss: 0.112 ##############################
# ########################### Epoch: 4 , --  batch: 278 / 313 ,    Test loss: 0.009, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 279 / 313 ,    Test loss: 0.189, accumulated average loss: 0.111 ##############################
# ########################### Epoch: 4 , --  batch: 280 / 313 ,    Test loss: 0.642, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 281 / 313 ,    Test loss: 0.005, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 282 / 313 ,    Test loss: 0.054, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 283 / 313 ,    Test loss: 0.110, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 284 / 313 ,    Test loss: 0.230, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 285 / 313 ,    Test loss: 0.138, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 286 / 313 ,    Test loss: 0.000, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 287 / 313 ,    Test loss: 0.309, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 288 / 313 ,    Test loss: 0.067, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 289 / 313 ,    Test loss: 0.080, accumulated average loss: 0.113 ##############################
# ########################### Epoch: 4 , --  batch: 290 / 313 ,    Test loss: 0.364, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 291 / 313 ,    Test loss: 0.128, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 292 / 313 ,    Test loss: 0.077, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 293 / 313 ,    Test loss: 0.204, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 294 / 313 ,    Test loss: 0.048, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 295 / 313 ,    Test loss: 0.128, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 296 / 313 ,    Test loss: 0.196, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 297 / 313 ,    Test loss: 0.047, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 298 / 313 ,    Test loss: 0.048, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 299 / 313 ,    Test loss: 0.217, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 300 / 313 ,    Test loss: 0.313, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 4 , --  batch: 301 / 313 ,    Test loss: 0.027, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 4 , --  batch: 302 / 313 ,    Test loss: 0.077, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 4 , --  batch: 303 / 313 ,    Test loss: 0.001, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 304 / 313 ,    Test loss: 0.209, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 4 , --  batch: 305 / 313 ,    Test loss: 0.010, accumulated average loss: 0.114 ##############################
# ########################### Epoch: 4 , --  batch: 306 / 313 ,    Test loss: 0.461, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 4 , --  batch: 307 / 313 ,    Test loss: 0.014, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 4 , --  batch: 308 / 313 ,    Test loss: 0.145, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 4 , --  batch: 309 / 313 ,    Test loss: 0.268, accumulated average loss: 0.116 ##############################
# ########################### Epoch: 4 , --  batch: 310 / 313 ,    Test loss: 0.017, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 4 , --  batch: 311 / 313 ,    Test loss: 0.001, accumulated average loss: 0.115 ##############################
# ########################### Epoch: 4 , --  batch: 312 / 313 ,    Test loss: 0.002, accumulated average loss: 0.115 ##############################
